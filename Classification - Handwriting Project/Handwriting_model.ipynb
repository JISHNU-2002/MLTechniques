# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
path_test = "/content/drive/MyDrive/Datasets/digit"

# %%
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2657 - accuracy: 0.9225
# Epoch 2/3
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1077 - accuracy: 0.9664
# Epoch 3/3
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0739 - accuracy: 0.9770

# %%
model.save('handwritten.model')

# %%
model = tf.keras.models.load_model('handwritten.model')

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print(loss)
print(accuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0959 - accuracy: 0.9711
# 0.09592798352241516
# 0.9710999727249146

# %%
image_number = 1
while os.path.isfile(f"{path_test}/digit{image_number}.png"):
    try:
        img = cv2.imread(f"{path_test}/digit{image_number}.png")[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print(f"digit = {np.argmax(prediction)}")
        plt.inshow(img[0],cmap=plt.cm.binay)
        plt.show()
    except:
        print("error")
    finally:
        image_number +=1
# Out:
# 1/1 [==============================] - 0s 163ms/step
# digit = 3
# error
